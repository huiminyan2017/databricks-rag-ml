# %%
restart_needed = False

try:
    import openai  # noqa: F401
except ImportError:
    # %pip install -U "openai>=1.0.0,<2.0.0"
    restart_needed = True

try:
    import databricks.vector_search  # noqa: F401
except ImportError:
    # %pip install databricks-vectorsearch
    restart_needed = True

if restart_needed:
    print("New packages installed — restarting Python kernel...")
    dbutils.library.restartPython()
else:
    print("All required packages already installed. No restart needed.")
