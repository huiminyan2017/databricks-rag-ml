# %% [markdown]
# ##### Flow:
# ```text
# User Question
#     ↓
# Embed question
#     ↓
# Vector similarity search
#     ↓
# Top-K chunks
#     ↓
# Prompt assembly
#     ↓
# LLM call
#     ↓
# Final answer
# ```
#
# ##### Prequisite
# You will have two Azure OpenAI deployments:
#
# Create in Azure AI Foundry / Azure OpenAI:
# - Embedding deployment (example name): text-embedding-3-small
# - Chat deployment (example name): gpt-4o-mini
#
# Azure OpenAI API calls use deployment names (not the underlying model name).
#
# ##### Input and Output:
# - Input:
#     - Table: `databricks_rag_demo.default.azure_compute_doc_embeddings`
#     - User question
#
# - Output: User's answer

# %% [markdown]
# Important design choice: How to do vector search?
#
# We have 3 options:
#
# - Option A — Naive cosine similarity in Spark (we'll start here)
# 	- Simple
# 	- Transparent
# 	- Works for thousands of chunks
# 	- Good for learning
#
# - Option B — Databricks Vector Search
# 	- Production-grade
# 	- Scalable
# 	- Index-based
# 	- We can move here later
#
# - Option C — External vector DB (Pinecone, Weaviate, etc.)
# 	- Overkill right now
#
# We'll start with Option A, then upgrade.

# %% [markdown]
# #### 04 - Retrieval-Augmented Generation (RAG)
#
# This notebook implements a basic RAG pipeline:
# 1. Embed user queries
# 2. Retrieve relevant document chunks
# 3. Assemble a grounded prompt
# 4. Generate an answer using an LLM

# %% [markdown]
# Vector Search (production retrieval)
#
# 1. Create the Vector Search endpoint + index (recommended via UI)
#
# - Databricks → Compute -> Vector Search
# - Create endpoint (name example): vs_azure_compute
# - Create index
#   - Type: Delta Sync index
#   - Name: azure_compute_docs_vs_index
#   - Source table: databricks_rag_demo.default.azure_compute_doc_embeddings
#   - Primary key: chunk_id
# 	- Embedding column: embedding
#
# 2. Query the index in Python
#
# Once endpoint + index exist, use the Vector Search client.

# %%
# %run ./00_install_deps_and_restart
# Out:
# Collecting openai<2.0.0,>=1.0.0
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting anyio<5,>=3.5.0 (from openai<2.0.0,>=1.0.0)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.0.0) (1.9.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.0.0)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.0.0)
#   Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from openai<2.0.0,>=1.0.0) (2.8.2)
# Collecting sniffio (from openai<2.0.0,>=1.0.0)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<2.0.0,>=1.0.0)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/57.7 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.11 in /databricks/python3/lib/python3.12/site-packages (from openai<2.0.0,>=1.0.0) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.0.0) (3.7)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.0.0) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.0.0)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.0.0)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=1.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=1.0.0) (2.20.1)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/948.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 809.0/948.6 kB 25.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 17.1 MB/s eta 0:00:00
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/113.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 6.9 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/73.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 5.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/78.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 6.2 MB/s eta 0:00:00
# Downloading jiter-0.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (361 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/361.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 16.0 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/78.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.2 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: tqdm, sniffio, jiter, h11, anyio, httpcore, httpx, openai
# Successfully installed anyio-4.12.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.12.0 openai-1.109.1 sniffio-1.3.1 tqdm-4.67.1
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Collecting databricks-vectorsearch
#   Downloading databricks_vectorsearch-0.63-py3-none-any.whl.metadata (2.8 kB)
# Collecting deprecation>=2 (from databricks-vectorsearch)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: mlflow-skinny<4,>=2.11.3 in /databricks/python3/lib/python3.12/site-packages (from databricks-vectorsearch) (2.19.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-vectorsearch) (4.24.1)
# Requirement already satisfied: requests>=2 in /databricks/python3/lib/python3.12/site-packages (from databricks-vectorsearch) (2.32.2)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from deprecation>=2->databricks-vectorsearch) (24.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (2.2.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (0.30.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (3.1.37)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (6.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (1.27.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (6.0.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2->databricks-vectorsearch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests>=2->databricks-vectorsearch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests>=2->databricks-vectorsearch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2->databricks-vectorsearch) (2024.6.2)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (2.35.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (3.17.0)
# Requirement already satisfied: deprecated>=1.2.6 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (0.48b0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (4.11.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /databricks/python3/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<4,>=2.11.3->databricks-vectorsearch) (0.4.8)
# Downloading databricks_vectorsearch-0.63-py3-none-any.whl (19 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: deprecation, databricks-vectorsearch
# Successfully installed databricks-vectorsearch-0.63 deprecation-2.1.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# New packages installed — restarting Python kernel...
# Warning: statements after `dbutils.library.restartPython()` will execute before Python is restarted.

# %%
# %run ./00_constants

# %%
# %run ./00_utils

# %%
# %run ./00_init_openai_client

# %%
import mlflow
# Disable mlflow autologging
mlflow.autolog(disable=True)
mlflow.openai.autolog(disable=True)

# %% [markdown]
# Vector Search (production retrieval)
#
# 3A) Create the Vector Search endpoint + index (recommended via UI)
#
# Fastest/least pain is UI:
# - Databricks -> Compute -> Vector Search
# - Create endpoint (name example): azure_compute_docs
# - Create index
#   - Type: Delta Sync index
#   - Source table: databricks_rag_demo.default.azure_compute_docs_embeddings
#   - Primary key: chunk_id
# 	- Embedding column: embedding
#
# 3B) Query the index in Python
#
# Once endpoint + index exist, use the Vector Search client.

# %%
questions = [
    "What is the difference between a normal Azure VM and an ephemeral VM?",
    "How do I resize an Azure virtual machine?",
    "What is Azure VM Scale Sets?",
    # "How does Azure handle VM disk persistence?",
    # "What is the difference between Spot VM and normal VM?",
    # "How do I enable accelerated networking?",
    # "What is Azure availability set vs availability zone?"
]

batch_ask(questions, k=5, retrievers=["A", "B"], do_eval=True, verbose=False)
# Out:
# ================================================================================
# Question: What is the difference between a normal Azure VM and an ephemeral VM?
# ================================================================================
#
# --- Retriever A ---
#
# --- Retriever B ---
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
#
# ================================================================================
# Question: How do I resize an Azure virtual machine?
# ================================================================================
#
# --- Retriever A ---
#
# --- Retriever B ---
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
#
# ================================================================================
# Question: What is Azure VM Scale Sets?
# ================================================================================
#
# --- Retriever A ---
#
# --- Retriever B ---
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# [NOTICE] Using a notebook authentication token. Recommended for development only. For improved performance, please use Service Principal based authentication. To disable this message, pass disable_notice=True.
# [{'query_id': 'e9f6e839-c5ad-415b-9cf0-6ad44ecc2a0f',
#   'question': 'What is the difference between a normal Azure VM and an ephemeral VM?',
#   'answer': 'The primary difference between a normal Azure VM and an ephemeral VM lies in the storage configuration of the operating system disk.\n\n1. **Normal Azure VM**:\n   - A normal Azure VM typically uses a standard managed OS disk that is persistent. This means that the OS disk retains its data even when the VM is stopped or deallocated. The OS disk can be backed up and restored, and it is suitable for applications that require data persistence.\n\n2. **Ephemeral VM**:\n   - An ephemeral VM, on the other hand, uses an ephemeral OS disk. This type of disk is temporary and does not retain data once the VM is stopped or deallocated. The data on an ephemeral OS disk is lost when the VM is deallocated, making it suitable for stateless applications or workloads that can tolerate interruptions. Ephemeral disks are typically faster because they are stored on local SSDs, providing better performance for certain workloads.\n\nIn summary, the key difference is that normal Azure VMs have persistent OS disks, while ephemeral VMs use temporary OS disks that do not retain data after the VM is stopped.',
#   'sources': [{'chunk_id': '19070d1dc7b14a46a6d58d254935f8db3a97b39aa99ac74e3865783a30a54e6e',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 5,
#     'category': 'virtual-machines',
#     'score': 0.5174035456941407,
#     'preview': 'more flexibility and scalability performance isolation easier maintenance improved security and access control for more information on these benefits see why should i use the data disk to store applic…'},
#    {'chunk_id': 'c2a5d7b954542e97418a122599e418aaed9b432ca1ceb59d21b9af5f815526bb',
#     'doc_id': 'virtual-machines/ecasv5-ecadsv5-series.md',
#     'title': 'ecasv5-ecadsv5-series',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/ecasv5-ecadsv5-series.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.4746385336504494,
#     'preview': 'title azure ecasv5 and ecadsv5 series description specifications for azure confidential computing s ecasv5 and ecadsv5 series confidential virtual machines author runcai ms author runcai ms reviewer m…'},
#    {'chunk_id': 'a9c2a386562c2540e4e948c74a30d4e5b74ed3c52d1d92753a37912130cb80d5',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 4,
#     'category': 'virtual-machines',
#     'score': 0.4720750699188078,
#     'preview': 'roles there are three main disk roles in azure the os disk the data disk and the temporary disk these roles map to disks that are attached to your virtual machine performance for each disk role works …'},
#    {'chunk_id': 'e2e19f61dc292776f305e00b590acb4ca1de9fc7439367788bc9db71bcb2adc6',
#     'doc_id': 'virtual-machines/spot-vms.md',
#     'title': 'spot-vms',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-vms.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.46477932169418595,
#     'preview': 'title use azure spot virtual machines description learn how to use azure spot virtual machines to save on costs author cynthn ms author cynthn ms service azure virtual machines ms subservice azure spo…'},
#    {'chunk_id': '0a9406dd63ba6aeae9e8a9e63cac680077d61026c26f665be45a13ab8b25e163',
#     'doc_id': 'virtual-machines/ebdsv5-ebsv5-series.md',
#     'title': 'ebdsv5-ebsv5-series',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/ebdsv5-ebsv5-series.md',
#     'chunk_index': 3,
#     'category': 'virtual-machines',
#     'score': 0.46347739447743885,
#     'preview': 'disk throughput iops mbps max burst uncached premium ssd disk throughput iops mbps max uncached ultra disk and premium ssd v2 disk throughput iops mbps max burst uncached ultra disk and premium ssd v2…'}],
#   'eval': {'evaluation_id': 'ed389a99-07d3-405e-9bd0-31c0b70b8e73',
#    'retrieval_relevance': 2,
#    'answer_relevance': 5,
#    'faithfulness': 3,
#    'notes': 'The answer provides a clear and accurate distinction between normal Azure VMs and ephemeral VMs, addressing the question directly. However, the retrieved excerpts do not contain relevant information about the differences between these VM types, which affects the faithfulness score as the answer is not directly supported by the provided excerpts.'}},
#  {'query_id': '8d759cd9-f704-4e63-ade5-944c33af3ba5',
#   'question': 'What is the difference between a normal Azure VM and an ephemeral VM?',
#   'answer': "The primary difference between a normal Azure VM and an ephemeral VM lies in the storage of the operating system disk.\n\n1. **Normal Azure VM**:\n   - A normal Azure VM typically uses a persistent OS disk, which means that the OS disk is stored on Azure's managed disk storage. This disk retains its data even if the VM is stopped or deallocated. The OS disk can be backed up, and you can manage it like any other disk in Azure.\n\n2. **Ephemeral VM**:\n   - An ephemeral VM, on the other hand, uses an ephemeral OS disk. This type of disk is not persistent and is stored on the local temporary storage of the VM. The data on an ephemeral OS disk is lost if the VM is deallocated or if there is a failure. Ephemeral disks are designed for scenarios where speed and performance are critical, and the loss of data is acceptable, such as in stateless applications or development environments.\n\nIn summary, the key difference is that normal Azure VMs have persistent OS disks that retain data across VM lifecycle events, while ephemeral VMs use non-persistent OS disks that do not retain data when the VM is stopped or deallocated.",
#   'sources': [{'chunk_id': '19070d1dc7b14a46a6d58d254935f8db3a97b39aa99ac74e3865783a30a54e6e',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 5.0,
#     'category': 'virtual-machines',
#     'score': None,
#     'preview': 'more flexibility and scalability performance isolation easier maintenance improved security and access control for more information on these benefits see why should i use the data disk to store applic…'},
#    {'chunk_id': 'c2a5d7b954542e97418a122599e418aaed9b432ca1ceb59d21b9af5f815526bb',
#     'doc_id': 'virtual-machines/ecasv5-ecadsv5-series.md',
#     'title': 'ecasv5-ecadsv5-series',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/ecasv5-ecadsv5-series.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machines',
#     'score': None,
#     'preview': 'title azure ecasv5 and ecadsv5 series description specifications for azure confidential computing s ecasv5 and ecadsv5 series confidential virtual machines author runcai ms author runcai ms reviewer m…'},
#    {'chunk_id': 'a9c2a386562c2540e4e948c74a30d4e5b74ed3c52d1d92753a37912130cb80d5',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 4.0,
#     'category': 'virtual-machines',
#     'score': None,
#     'preview': 'roles there are three main disk roles in azure the os disk the data disk and the temporary disk these roles map to disks that are attached to your virtual machine performance for each disk role works …'},
#    {'chunk_id': 'e2e19f61dc292776f305e00b590acb4ca1de9fc7439367788bc9db71bcb2adc6',
#     'doc_id': 'virtual-machines/spot-vms.md',
#     'title': 'spot-vms',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-vms.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machines',
#     'score': None,
#     'preview': 'title use azure spot virtual machines description learn how to use azure spot virtual machines to save on costs author cynthn ms author cynthn ms service azure virtual machines ms subservice azure spo…'},
#    {'chunk_id': '0a9406dd63ba6aeae9e8a9e63cac680077d61026c26f665be45a13ab8b25e163',
#     'doc_id': 'virtual-machines/ebdsv5-ebsv5-series.md',
#     'title': 'ebdsv5-ebsv5-series',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/ebdsv5-ebsv5-series.md',
#     'chunk_index': 3.0,
#     'category': 'virtual-machines',
#     'score': None,
#     'preview': 'disk throughput iops mbps max burst uncached premium ssd disk throughput iops mbps max uncached ultra disk and premium ssd v2 disk throughput iops mbps max burst uncached ultra disk and premium ssd v2…'}],
#   'eval': {'evaluation_id': '78d579ac-751b-48ca-b5ce-316bb53d6f93',
#    'retrieval_relevance': 1,
#    'answer_relevance': 5,
#    'faithfulness': 1,
#    'notes': 'The retrieved excerpts do not provide relevant information about the differences between normal Azure VMs and ephemeral VMs. The answer is well-structured and directly addresses the question, but it is not supported by the provided excerpts, leading to a low faithfulness score.'}},
#  {'query_id': '7f89aade-6341-412c-8289-320fa7ec0a3b',
#   'question': 'How do I resize an Azure virtual machine?',
#   'answer': 'To resize an Azure virtual machine, you need to follow these steps:\n\n1. **Understand the Resize Operation**: Be aware that resizing a virtual machine (VM) will cause a reboot. Therefore, plan for downtime during this operation. You can resize a VM either within the same series or to a different series.\n\n2. **Use Azure Portal or CLI**: You can resize a VM using the Azure Portal or Azure CLI. \n\n   - **Using Azure Portal**:\n     - Navigate to the Azure Portal and select the virtual machine you want to resize.\n     - In the VM\'s menu, select "Size" under the "Settings" section.\n     - Choose the new size from the available options and click "Resize".\n\n   - **Using Azure CLI**:\n     - Open the Azure Cloud Shell or your local terminal with Azure CLI installed.\n     - Use the following command to resize the VM:\n       ```bash\n       az vm resize --resource-group <your-resource-group> --name <your-vm-name> --size <new-size>\n       ```\n     - Replace `<your-resource-group>`, `<your-vm-name>`, and `<new-size>` with your specific values.\n\n3. **Check Supported Sizes**: Ensure that the new size you want to resize to is supported for your VM\'s current configuration and region.\n\n4. **Monitor the Resize Operation**: After initiating the resize, monitor the operation to ensure it completes successfully.\n\nRemember that specialized marketplace offerings, such as SQL Server on virtual machines, are not supported for resizing.',
#   'sources': [{'chunk_id': 'b73244965d826d62f4e6eb798b76816ba64f33e486d8d0ccb7394e85928a8a51',
#     'doc_id': 'virtual-machines/vm-customization.md',
#     'title': 'vm-customization',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/vm-customization.md',
#     'chunk_index': 4,
#     'category': 'virtual-machines',
#     'score': 0.6016232896712848,
#     'preview': 'doesn t support the setting the operation is blocked or error anytime you resize a vm either within the same series or to a different series a vm reboot occurs plan for downtime during the resize oper…'},
#    {'chunk_id': '6ad880e0c258aa5473a477c05e67934855620c658a3cb5f233dc305aa53516b2',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-cli.md',
#     'title': 'flexible-virtual-machine-scale-sets-cli',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-cli.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5871466398757949,
#     'preview': 'title create virtual machines in a flexible scale set using azure cli description learn how to create a virtual machine scale set in flexible orchestration mode using azure cli author fitzgeraldsteele…'},
#    {'chunk_id': '89bcdc3c6deb2b821386469415e298884bf800fbfe8ec9fc5b2bbadefed550d3',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-autoscale-portal.md',
#     'title': 'virtual-machine-scale-sets-autoscale-portal',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-autoscale-portal.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5761801812159234,
#     'preview': 'title autoscale virtual machine scale sets in the azure portal description how to create autoscale rules for virtual machine scale sets in the azure portal author brittanyrowe ms author brittanyrowe m…'},
#    {'chunk_id': '3a68cb2bab09cccdd1018119a2ab8be27435801ed4bc88628a54a688d308b9bd',
#     'doc_id': 'virtual-machine-scale-sets/use-spot.md',
#     'title': 'use-spot',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/use-spot.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5753547729216547,
#     'preview': 'title create a scale set that uses azure spot virtual machines description learn how to create azure virtual machine scale sets that use azure spot virtual machines to save on costs author cynthn ms a…'},
#    {'chunk_id': 'a55f29614cede88cdd48dc9c139bf92984eed8176152678873fe2d2bf8508ace',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'title': 'flexible-virtual-machine-scale-sets-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5751507339283991,
#     'preview': 'title create virtual machines in a scale set using azure powershell description learn how to create a virtual machine scale set in flexible orchestration mode using powershell author fitzgeraldsteele …'}],
#   'eval': {'evaluation_id': '7448ba14-74a6-4db2-a1f5-09fc52411498',
#    'retrieval_relevance': 3,
#    'answer_relevance': 5,
#    'faithfulness': 4,
#    'notes': 'The retrieved excerpts provide some relevant information about resizing VMs, including the need for a reboot and that certain marketplace offerings are not supported. However, the answer includes more detailed steps and context that are not fully covered in the excerpts, leading to a slightly lower score for faithfulness.'}},
#  {'query_id': 'f6d7f27f-f630-4ea1-a50f-46997963d162',
#   'question': 'How do I resize an Azure virtual machine?',
#   'answer': 'To resize an Azure virtual machine, you need to follow these general steps:\n\n1. **Prepare for Downtime**: Be aware that resizing a virtual machine (VM) will cause a reboot. Plan for downtime during this operation.\n\n2. **Access Azure Portal or CLI**: You can resize a VM using the Azure Portal, Azure CLI, or Azure PowerShell.\n\n3. **Using Azure Portal**:\n   - Navigate to the Azure Portal and select the virtual machine you want to resize.\n   - In the VM\'s menu, look for the "Size" option.\n   - Select the new size from the available options. Ensure that the new size is compatible with the current VM series.\n   - Click "Resize" to apply the changes.\n\n4. **Using Azure CLI**:\n   - Open Azure Cloud Shell or your local terminal with Azure CLI installed.\n   - Use the following command to resize the VM:\n     ```bash\n     az vm resize --resource-group <your-resource-group> --name <your-vm-name> --size <new-size>\n     ```\n   - Replace `<your-resource-group>`, `<your-vm-name>`, and `<new-size>` with your specific values.\n\n5. **Using Azure PowerShell**:\n   - Open Azure Cloud Shell or your local PowerShell with Azure module installed.\n   - Use the following command to resize the VM:\n     ```powershell\n     Resize-AzVM -ResourceGroupName <your-resource-group> -Name <your-vm-name> -Size <new-size>\n     ```\n   - Again, replace `<your-resource-group>`, `<your-vm-name>`, and `<new-size>` with your specific values.\n\n6. **Confirm Changes**: After resizing, verify that the VM is running with the new size by checking its properties in the Azure Portal or using CLI/PowerShell commands.\n\nRemember that resizing is only supported within the same series or to a different series that is compatible with your VM. Specialized marketplace images may not support resizing.',
#   'sources': [{'chunk_id': 'b73244965d826d62f4e6eb798b76816ba64f33e486d8d0ccb7394e85928a8a51',
#     'doc_id': 'virtual-machines/vm-customization.md',
#     'title': 'vm-customization',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/vm-customization.md',
#     'chunk_index': 4.0,
#     'category': 'virtual-machines',
#     'score': None,
#     'preview': 'doesn t support the setting the operation is blocked or error anytime you resize a vm either within the same series or to a different series a vm reboot occurs plan for downtime during the resize oper…'},
#    {'chunk_id': '6ad880e0c258aa5473a477c05e67934855620c658a3cb5f233dc305aa53516b2',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-cli.md',
#     'title': 'flexible-virtual-machine-scale-sets-cli',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-cli.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title create virtual machines in a flexible scale set using azure cli description learn how to create a virtual machine scale set in flexible orchestration mode using azure cli author fitzgeraldsteele…'},
#    {'chunk_id': '89bcdc3c6deb2b821386469415e298884bf800fbfe8ec9fc5b2bbadefed550d3',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-autoscale-portal.md',
#     'title': 'virtual-machine-scale-sets-autoscale-portal',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-autoscale-portal.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title autoscale virtual machine scale sets in the azure portal description how to create autoscale rules for virtual machine scale sets in the azure portal author brittanyrowe ms author brittanyrowe m…'},
#    {'chunk_id': '3a68cb2bab09cccdd1018119a2ab8be27435801ed4bc88628a54a688d308b9bd',
#     'doc_id': 'virtual-machine-scale-sets/use-spot.md',
#     'title': 'use-spot',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/use-spot.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title create a scale set that uses azure spot virtual machines description learn how to create azure virtual machine scale sets that use azure spot virtual machines to save on costs author cynthn ms a…'},
#    {'chunk_id': 'a55f29614cede88cdd48dc9c139bf92984eed8176152678873fe2d2bf8508ace',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'title': 'flexible-virtual-machine-scale-sets-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title create virtual machines in a scale set using azure powershell description learn how to create a virtual machine scale set in flexible orchestration mode using powershell author fitzgeraldsteele …'}],
#   'eval': {'evaluation_id': 'e1570c26-d262-4e81-80cd-8b9929f73b77',
#    'retrieval_relevance': 2,
#    'answer_relevance': 5,
#    'faithfulness': 2,
#    'notes': 'The answer provides a detailed and accurate process for resizing an Azure virtual machine, which is relevant to the question. However, the retrieved excerpts do not directly support the answer, and they contain information about resizing that is incomplete and somewhat misleading. The first excerpt mentions that resizing causes a reboot and that it is blocked under certain conditions, but it does not provide a complete guide or the necessary commands for resizing, leading to a lower faithfulness score.'}},
#  {'query_id': '534688cd-03c9-4729-8837-e38e27866f33',
#   'question': 'What is Azure VM Scale Sets?',
#   'answer': 'Azure Virtual Machine Scale Sets (VMSS) are a service that allows you to deploy and manage a set of identical, auto-scaling virtual machines (VMs). They enable you to create and manage a group of VMs that can automatically increase or decrease in number based on demand, ensuring that your applications have the necessary resources to handle varying workloads.\n\nKey features of Azure VM Scale Sets include:\n\n1. **Auto-Scaling**: VMSS can automatically adjust the number of VM instances in response to demand, helping to optimize resource usage and costs.\n\n2. **Uniform and Flexible Orchestration Modes**: VMSS can operate in two orchestration modes:\n   - **Uniform Orchestration**: All VMs in the scale set are identical and managed as a single unit.\n   - **Flexible Orchestration**: Allows for more diverse VM configurations and is recommended for new workloads.\n\n3. **Integration with Azure Load Balancer**: VMSS can be integrated with Azure Load Balancer to distribute traffic across the VMs, enhancing availability and performance.\n\n4. **Large Scale Sets**: VMSS can scale up to 1,000 VMs, making them suitable for large applications requiring extensive resources.\n\n5. **Managed Disks**: VMSS is designed to work with Azure Managed Disks, simplifying storage management and improving performance.\n\n6. **Placement Groups**: VMSS can be configured to use multiple placement groups, which helps in managing fault domains and upgrade domains for high availability.\n\nOverall, Azure VM Scale Sets provide a powerful way to manage large-scale applications in the cloud, allowing for efficient deployment, scaling, and management of virtual machines.',
#   'sources': [{'chunk_id': 'a55f29614cede88cdd48dc9c139bf92984eed8176152678873fe2d2bf8508ace',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'title': 'flexible-virtual-machine-scale-sets-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6934008236342614,
#     'preview': 'title create virtual machines in a scale set using azure powershell description learn how to create a virtual machine scale set in flexible orchestration mode using powershell author fitzgeraldsteele …'},
#    {'chunk_id': 'b66bc43d73eb50039c923a19456ba339e557c7a0b59fc2b76e463dd54dd5e3ff',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'title': 'virtual-machine-scale-sets-placement-groups',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.681542195955353,
#     'preview': 'title virtual machine scale sets and placement groups description what you need to know about large azure virtual machine scale sets in order to use them in your application author mimckitt ms author …'},
#    {'chunk_id': '162dee68b71e7da4734d0ae355f4df86f05137682b1ddc3e88e07fb0b8c2e944',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-manage-powershell.md',
#     'title': 'virtual-machine-scale-sets-manage-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-manage-powershell.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6759886038350076,
#     'preview': 'title manage virtual machine scale sets with azure powershell description common azure powershell cmdlets to manage virtual machine scale sets such as how to start and stop an instance or change the s…'},
#    {'chunk_id': 'd5d9b31f8a367e73768a1d3bdfd0fcfb21c625aa067db4f45dca0263b311eff2',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'title': 'virtual-machine-scale-sets-placement-groups',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'chunk_index': 1,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6736486410743955,
#     'preview': 'data disks large scale sets enable you to deploy a scalable infrastructure consisting of thousands of vcpus and petabytes of storage as a single operation placement groups what makes a _large_ scale s…'},
#    {'chunk_id': '67e19723ab1c51684fe982143fbaeb0828e30fd7e836ed0dbef158635e69a7f0',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-upgrade-scale-set.md',
#     'title': 'virtual-machine-scale-sets-upgrade-scale-set',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-upgrade-scale-set.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.668091952599096,
#     'preview': 'title modify an azure virtual machine scale set description learn how to modify and update an azure virtual machine scale set with the rest apis azure powershell and azure cli author mimckitt ms autho…'}],
#   'eval': {'evaluation_id': '47ffe13b-6837-4485-9703-6bae91396999',
#    'retrieval_relevance': 5,
#    'answer_relevance': 5,
#    'faithfulness': 5,
#    'notes': 'The retrieved excerpts provide relevant information about Azure VM Scale Sets, including their features, orchestration modes, and scaling capabilities, which directly support the answer provided.'}},
#  {'query_id': 'c1d014f3-80a0-480d-9e67-75c1c60b9539',
#   'question': 'What is Azure VM Scale Sets?',
#   'answer': 'Azure Virtual Machine Scale Sets (VMSS) are a service that allows you to deploy and manage a set of identical, auto-scaling virtual machines (VMs) in Azure. They enable you to create and manage a group of VMs that can automatically increase or decrease in number based on demand, ensuring high availability and scalability for your applications.\n\nKey features of Azure VM Scale Sets include:\n\n1. **Auto-Scaling**: VMSS can automatically adjust the number of VM instances based on predefined rules, such as CPU usage or memory consumption, allowing for efficient resource utilization.\n\n2. **Uniform and Flexible Orchestration Modes**: VMSS can operate in uniform orchestration mode, where all VMs are identical and managed as a single unit, or flexible orchestration mode, which allows for more diverse VM configurations and management.\n\n3. **Integration with Load Balancers**: VMSS can be integrated with Azure Load Balancer to distribute traffic among the VMs, ensuring that applications remain responsive and available.\n\n4. **Managed Disks**: VMSS supports Azure Managed Disks, which simplifies disk management and improves performance and reliability.\n\n5. **Placement Groups**: For large scale sets, VMSS can utilize multiple placement groups, allowing for better fault tolerance and resource management.\n\n6. **Lifecycle Management**: Azure provides PowerShell and CLI tools to manage the lifecycle of VMSS, including creating, updating, and deleting scale sets and their instances.\n\nOverall, Azure VM Scale Sets are designed to provide a scalable and efficient infrastructure for applications that require high availability and the ability to handle varying workloads.',
#   'sources': [{'chunk_id': 'a55f29614cede88cdd48dc9c139bf92984eed8176152678873fe2d2bf8508ace',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'title': 'flexible-virtual-machine-scale-sets-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title create virtual machines in a scale set using azure powershell description learn how to create a virtual machine scale set in flexible orchestration mode using powershell author fitzgeraldsteele …'},
#    {'chunk_id': 'b66bc43d73eb50039c923a19456ba339e557c7a0b59fc2b76e463dd54dd5e3ff',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'title': 'virtual-machine-scale-sets-placement-groups',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title virtual machine scale sets and placement groups description what you need to know about large azure virtual machine scale sets in order to use them in your application author mimckitt ms author …'},
#    {'chunk_id': '162dee68b71e7da4734d0ae355f4df86f05137682b1ddc3e88e07fb0b8c2e944',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-manage-powershell.md',
#     'title': 'virtual-machine-scale-sets-manage-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-manage-powershell.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title manage virtual machine scale sets with azure powershell description common azure powershell cmdlets to manage virtual machine scale sets such as how to start and stop an instance or change the s…'},
#    {'chunk_id': 'd5d9b31f8a367e73768a1d3bdfd0fcfb21c625aa067db4f45dca0263b311eff2',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'title': 'virtual-machine-scale-sets-placement-groups',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'chunk_index': 1.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'data disks large scale sets enable you to deploy a scalable infrastructure consisting of thousands of vcpus and petabytes of storage as a single operation placement groups what makes a _large_ scale s…'},
#    {'chunk_id': '67e19723ab1c51684fe982143fbaeb0828e30fd7e836ed0dbef158635e69a7f0',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-upgrade-scale-set.md',
#     'title': 'virtual-machine-scale-sets-upgrade-scale-set',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-upgrade-scale-set.md',
#     'chunk_index': 0.0,
#     'category': 'virtual-machine-scale-sets',
#     'score': None,
#     'preview': 'title modify an azure virtual machine scale set description learn how to modify and update an azure virtual machine scale set with the rest apis azure powershell and azure cli author mimckitt ms autho…'}],
#   'eval': {'evaluation_id': '7c53cb4c-3e9a-4ff1-8849-13c9ec54b15b',
#    'retrieval_relevance': 5,
#    'answer_relevance': 5,
#    'faithfulness': 5,
#    'notes': 'The retrieved excerpts provide relevant information about Azure VM Scale Sets, including their features and management, which directly supports the answer given.'}}]
