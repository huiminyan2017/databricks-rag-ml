# %%
# ----------------------------
# Unity Catalog namespace
# ----------------------------
CATALOG = "databricks_rag_demo"
SCHEMA  = "default"

# ----------------------------
# Raw ingestion tables
# ----------------------------
RAW_DOCS_TABLE = f"{CATALOG}.{SCHEMA}.raw_azure_compute_docs"

# ----------------------------
# Chunking
# ----------------------------
CHUNKS_TABLE = f"{CATALOG}.{SCHEMA}.azure_compute_doc_chunks"

# ----------------------------
# Embeddings
# ----------------------------
EMB_TABLE = f"{CATALOG}.{SCHEMA}.azure_compute_doc_embeddings"

# ----------------------------
# RAG logging
# ----------------------------
RAG_LOG_TABLE = f"{CATALOG}.{SCHEMA}.rag_query_logs"

# ----------------------------
# RAG evaluation
# ----------------------------
RAG_EVAL_TABLE = f"{CATALOG}.{SCHEMA}.rag_evaluations"

# %%
# ----------------------------
# Vector Search
# ----------------------------
VS_ENDPOINT = "azure_compute_docs"
VS_INDEX = f"{CATALOG}.{SCHEMA}.azure_compute_docs_vs_index"

# %%
# ----------------------------
# Repo path that we will download source docs
# ----------------------------
DOC_REPO_URL = "https://github.com/MicrosoftDocs/azure-compute-docs.git"

# ----------------------------
# Local path that host downloaded docs
# ----------------------------
DOC_LOCAL_DOWNLOAD_DIR = "/tmp/azure_compute_docs"

# %%
# ----------------------------
#  Only include limited docs for each category, because whole dataset is very large and thing like embedding can be expensive if we do it for all
#  This is useful during testing.
# ----------------------------

MAX_DOCS_PER_CATEGORY = 50

# %%
# ----------------------------
# Embedding model deployment name
# ----------------------------
EMBEDDING_DEPLOYMENT = "text-embedding-3-small" # change if needed

# ----------------------------
# Chat model deployment name
# ----------------------------
CHAT_DEPLOYMENT      = "gpt-4o-mini" # change if needed
