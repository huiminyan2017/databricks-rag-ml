# %% [markdown]
# ##### Flow:
# ```text
# User Question
#     ↓
# Embed question
#     ↓
# Vector similarity search
#     ↓
# Top-K chunks
#     ↓
# Prompt assembly
#     ↓
# LLM call
#     ↓
# Final answer
# ```
#
# ##### Prequisite
# You will have two Azure OpenAI deployments:
#
# Create in Azure AI Foundry / Azure OpenAI:
# - Embedding deployment (example name): text-embedding-3-small
# - Chat deployment (example name): gpt-4o-mini
#
# Azure OpenAI API calls use deployment names (not the underlying model name).
#
# ##### Input and Output:
# - Input:
#     - Table: `databricks_rag_demo.default.azure_compute_doc_embeddings`
#     - User question
#
# - Output: User's answer

# %% [markdown]
# Important design choice: How to do vector search?
#
# We have 3 options:
#
# - Option A — Naive cosine similarity in Spark (we'll start here)
# 	- Simple
# 	- Transparent
# 	- Works for thousands of chunks
# 	- Good for learning
#
# - Option B — Databricks Vector Search
# 	- Production-grade
# 	- Scalable
# 	- Index-based
# 	- We can move here later
#
# - Option C — External vector DB (Pinecone, Weaviate, etc.)
# 	- Overkill right now
#
# We'll start with Option A, then upgrade.

# %% [markdown]
# #### 04 - Retrieval-Augmented Generation (RAG)
#
# This notebook implements a basic RAG pipeline:
# 1. Embed user queries
# 2. Retrieve relevant document chunks
# 3. Assemble a grounded prompt
# 4. Generate an answer using an LLM

# %%
# %run ./00_install_deps_and_restart
# Out:
# All required packages already installed. No restart needed.

# %%
# %run ./00_constants

# %%
# %run ./00_utils

# %%
# %run ./00_init_openai_client

# %%
import mlflow
# Disable mlflow autologging
mlflow.autolog(disable=True)
mlflow.openai.autolog(disable=True)

# %% [markdown]
# Vector Search (production retrieval)
#
# 3A) Create the Vector Search endpoint + index (recommended via UI)
#
# Fastest/least pain is UI:
# - Databricks → Mosaic AI / Vector Search
# - Create endpoint (name example): vs_azure_compute
# - Create index
#   - Type: Delta Sync index
#   - Source table: databricks_rag_demo.default.azure_compute_doc_embeddings
#   - Primary key: chunk_id
# 	- Embedding column: embedding
#
# 3B) Query the index in Python
#
# Once endpoint + index exist, use the Vector Search client.

# %%
questions = [
    "What is the difference between a normal Azure VM and an ephemeral VM?",
    "How do I resize an Azure virtual machine?",
    "What is Azure VM Scale Sets?",
    "How does Azure handle VM disk persistence?",
    "What is the difference between Spot VM and normal VM?",
    # "How do I enable accelerated networking?",
    # "What is Azure availability set vs availability zone?"
]

batch_ask(questions, k=5, retrievers=["A"], do_eval=True, verbose=False)
# Out:
# ================================================================================
# Question: What is the difference between a normal Azure VM and an ephemeral VM?
# ================================================================================
#
# --- Retriever A ---
#
# ================================================================================
# Question: How do I resize an Azure virtual machine?
# ================================================================================
#
# --- Retriever A ---
#
# ================================================================================
# Question: What is Azure VM Scale Sets?
# ================================================================================
#
# --- Retriever A ---
#
# ================================================================================
# Question: How does Azure handle VM disk persistence?
# ================================================================================
#
# --- Retriever A ---
#
# ================================================================================
# Question: What is the difference between Spot VM and normal VM?
# ================================================================================
#
# --- Retriever A ---
# [{'query_id': 'aa9f09f7-ffca-47b8-a349-98b7cc2cddd8',
#   'question': 'What is the difference between a normal Azure VM and an ephemeral VM?',
#   'answer': 'The primary difference between a normal Azure VM and an ephemeral VM lies in how the operating system disk is managed and the persistence of data.\n\n1. **Operating System Disk**:\n   - **Normal Azure VM**: A standard Azure VM typically uses a managed OS disk that is persistent. This means that the OS disk retains its data even when the VM is stopped or deallocated. The OS disk can be backed up, and data on it is preserved across reboots and maintenance events.\n   - **Ephemeral VM**: An ephemeral VM, on the other hand, uses an ephemeral OS disk, which is a temporary disk that is not persistent. This means that the data on the OS disk is lost if the VM is stopped or deallocated. Ephemeral disks are designed for scenarios where the OS can be quickly redeployed, and the loss of data is acceptable.\n\n2. **Use Cases**:\n   - **Normal Azure VM**: Suitable for applications that require data persistence, such as databases or applications that need to retain state across reboots.\n   - **Ephemeral VM**: Ideal for stateless applications, development and testing environments, or scenarios where rapid scaling and deployment are needed without the overhead of managing persistent storage.\n\n3. **Performance and Cost**:\n   - **Normal Azure VM**: Managed disks can incur additional costs for storage and may have different performance characteristics based on the disk type (Standard HDD, Standard SSD, Premium SSD).\n   - **Ephemeral VM**: Typically offers lower costs since it does not require persistent storage, and can provide faster provisioning times due to the nature of ephemeral storage.\n\nIn summary, the key difference is that normal Azure VMs use persistent managed disks, while ephemeral VMs use temporary disks that do not retain data when the VM is stopped or deallocated.',
#   'sources': [{'chunk_id': '19070d1dc7b14a46a6d58d254935f8db3a97b39aa99ac74e3865783a30a54e6e',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 5,
#     'category': 'virtual-machines',
#     'score': 0.5174035456941408,
#     'preview': 'more flexibility and scalability performance isolation easier maintenance improved security and access control for more information on these benefits see why should i use the data disk to store applic…'},
#    {'chunk_id': 'c2a5d7b954542e97418a122599e418aaed9b432ca1ceb59d21b9af5f815526bb',
#     'doc_id': 'virtual-machines/ecasv5-ecadsv5-series.md',
#     'title': 'ecasv5-ecadsv5-series',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/ecasv5-ecadsv5-series.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.4746385336504495,
#     'preview': 'title azure ecasv5 and ecadsv5 series description specifications for azure confidential computing s ecasv5 and ecadsv5 series confidential virtual machines author runcai ms author runcai ms reviewer m…'},
#    {'chunk_id': 'a9c2a386562c2540e4e948c74a30d4e5b74ed3c52d1d92753a37912130cb80d5',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 4,
#     'category': 'virtual-machines',
#     'score': 0.4720750699188078,
#     'preview': 'roles there are three main disk roles in azure the os disk the data disk and the temporary disk these roles map to disks that are attached to your virtual machine performance for each disk role works …'},
#    {'chunk_id': 'e2e19f61dc292776f305e00b590acb4ca1de9fc7439367788bc9db71bcb2adc6',
#     'doc_id': 'virtual-machines/spot-vms.md',
#     'title': 'spot-vms',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-vms.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.46477932169418595,
#     'preview': 'title use azure spot virtual machines description learn how to use azure spot virtual machines to save on costs author cynthn ms author cynthn ms service azure virtual machines ms subservice azure spo…'},
#    {'chunk_id': '0a9406dd63ba6aeae9e8a9e63cac680077d61026c26f665be45a13ab8b25e163',
#     'doc_id': 'virtual-machines/ebdsv5-ebsv5-series.md',
#     'title': 'ebdsv5-ebsv5-series',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/ebdsv5-ebsv5-series.md',
#     'chunk_index': 3,
#     'category': 'virtual-machines',
#     'score': 0.4634773944774389,
#     'preview': 'disk throughput iops mbps max burst uncached premium ssd disk throughput iops mbps max uncached ultra disk and premium ssd v2 disk throughput iops mbps max burst uncached ultra disk and premium ssd v2…'}],
#   'eval': {'evaluation_id': 'b363879a-8cd3-4872-8ad5-29ea219839fb',
#    'retrieval_relevance': 2,
#    'answer_relevance': 5,
#    'faithfulness': 3,
#    'notes': 'The answer provides a clear and detailed explanation of the differences between normal Azure VMs and ephemeral VMs, addressing the question directly. However, the retrieved excerpts do not contain relevant information about ephemeral VMs, which affects the faithfulness score as the answer is not directly supported by the provided excerpts.'}},
#  {'query_id': '5fecd526-9c6b-4afd-b5b6-d381c44f149c',
#   'question': 'How do I resize an Azure virtual machine?',
#   'answer': 'To resize an Azure virtual machine, you need to follow these general steps:\n\n1. **Prepare for Downtime**: Be aware that resizing a virtual machine (VM) will cause a reboot. Plan for downtime during this operation, as the VM will be temporarily unavailable.\n\n2. **Access Azure Portal or CLI**: You can resize a VM using the Azure Portal, Azure CLI, or Azure PowerShell. \n\n3. **Using Azure Portal**:\n   - Navigate to the Azure Portal and select the virtual machine you want to resize.\n   - In the VM\'s settings, look for the "Size" option in the menu.\n   - Select "Size" to view available VM sizes.\n   - Choose the desired size and click "Resize" to apply the changes.\n\n4. **Using Azure CLI**:\n   - Open Azure Cloud Shell or your local terminal with Azure CLI installed.\n   - Use the following command to resize the VM:\n     ```bash\n     az vm resize --resource-group <your-resource-group> --name <your-vm-name> --size <new-size>\n     ```\n   - Replace `<your-resource-group>`, `<your-vm-name>`, and `<new-size>` with your specific values.\n\n5. **Using Azure PowerShell**:\n   - Open Azure Cloud Shell or your local PowerShell with Azure modules installed.\n   - Use the following command to resize the VM:\n     ```powershell\n     Resize-AzVM -ResourceGroupName <your-resource-group> -Name <your-vm-name> -Size <new-size>\n     ```\n   - Again, replace `<your-resource-group>`, `<your-vm-name>`, and `<new-size>` with your specific values.\n\n6. **Confirm the Resize**: After the operation completes, verify that the VM has been resized successfully by checking its size in the Azure Portal or using the CLI/PowerShell commands.\n\nRemember that resizing is only supported for certain VM series and types, so ensure that the new size is compatible with your VM\'s current configuration.',
#   'sources': [{'chunk_id': 'b73244965d826d62f4e6eb798b76816ba64f33e486d8d0ccb7394e85928a8a51',
#     'doc_id': 'virtual-machines/vm-customization.md',
#     'title': 'vm-customization',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/vm-customization.md',
#     'chunk_index': 4,
#     'category': 'virtual-machines',
#     'score': 0.6016232896712849,
#     'preview': 'doesn t support the setting the operation is blocked or error anytime you resize a vm either within the same series or to a different series a vm reboot occurs plan for downtime during the resize oper…'},
#    {'chunk_id': '6ad880e0c258aa5473a477c05e67934855620c658a3cb5f233dc305aa53516b2',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-cli.md',
#     'title': 'flexible-virtual-machine-scale-sets-cli',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-cli.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5871466398757951,
#     'preview': 'title create virtual machines in a flexible scale set using azure cli description learn how to create a virtual machine scale set in flexible orchestration mode using azure cli author fitzgeraldsteele…'},
#    {'chunk_id': '89bcdc3c6deb2b821386469415e298884bf800fbfe8ec9fc5b2bbadefed550d3',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-autoscale-portal.md',
#     'title': 'virtual-machine-scale-sets-autoscale-portal',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-autoscale-portal.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5761801812159234,
#     'preview': 'title autoscale virtual machine scale sets in the azure portal description how to create autoscale rules for virtual machine scale sets in the azure portal author brittanyrowe ms author brittanyrowe m…'},
#    {'chunk_id': '3a68cb2bab09cccdd1018119a2ab8be27435801ed4bc88628a54a688d308b9bd',
#     'doc_id': 'virtual-machine-scale-sets/use-spot.md',
#     'title': 'use-spot',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/use-spot.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5753547729216548,
#     'preview': 'title create a scale set that uses azure spot virtual machines description learn how to create azure virtual machine scale sets that use azure spot virtual machines to save on costs author cynthn ms a…'},
#    {'chunk_id': 'a55f29614cede88cdd48dc9c139bf92984eed8176152678873fe2d2bf8508ace',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'title': 'flexible-virtual-machine-scale-sets-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5751507339283991,
#     'preview': 'title create virtual machines in a scale set using azure powershell description learn how to create a virtual machine scale set in flexible orchestration mode using powershell author fitzgeraldsteele …'}],
#   'eval': {'evaluation_id': 'b477f501-3afc-4a97-ad6f-22011f580068',
#    'retrieval_relevance': 2,
#    'answer_relevance': 5,
#    'faithfulness': 2,
#    'notes': 'The answer provides a detailed and accurate process for resizing an Azure virtual machine, which is relevant to the question. However, the retrieved excerpts do not directly support the answer, particularly regarding the steps involved in resizing a VM. The first excerpt mentions downtime during resizing but lacks specific instructions or commands that align with the answer.'}},
#  {'query_id': 'bae458ca-5555-4cf2-b40b-a357c3670e78',
#   'question': 'What is Azure VM Scale Sets?',
#   'answer': 'Azure Virtual Machine Scale Sets (VMSS) are a service that allows you to deploy and manage a set of identical, auto-scaling virtual machines (VMs). They enable you to create and manage a group of VMs that can automatically increase or decrease in number based on demand, ensuring that your applications can handle varying workloads efficiently.\n\nKey features of Azure VM Scale Sets include:\n\n1. **Auto-Scaling**: VMSS can automatically adjust the number of VM instances in response to demand, helping to optimize resource usage and costs.\n\n2. **Uniform and Flexible Orchestration Modes**: VMSS can operate in either uniform orchestration mode, where all VMs are identical, or flexible orchestration mode, which allows for more diverse configurations and scaling options.\n\n3. **Integration with Azure Load Balancer**: VMSS can be integrated with Azure Load Balancer to distribute traffic across the VMs, ensuring high availability and reliability.\n\n4. **Management and Automation**: Azure PowerShell and Azure CLI can be used to manage VMSS, allowing for automation of tasks such as scaling, starting, stopping, and updating VMs.\n\n5. **Large Scale Sets**: VMSS can scale to thousands of VMs, with the capability to create large scale sets that can contain multiple placement groups, enhancing resource management for extensive applications.\n\nOverall, Azure VM Scale Sets provide a powerful and flexible way to manage large numbers of VMs, making them ideal for applications that require high availability, scalability, and efficient resource management.',
#   'sources': [{'chunk_id': 'a55f29614cede88cdd48dc9c139bf92984eed8176152678873fe2d2bf8508ace',
#     'doc_id': 'virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'title': 'flexible-virtual-machine-scale-sets-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/flexible-virtual-machine-scale-sets-powershell.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6934008236342617,
#     'preview': 'title create virtual machines in a scale set using azure powershell description learn how to create a virtual machine scale set in flexible orchestration mode using powershell author fitzgeraldsteele …'},
#    {'chunk_id': 'b66bc43d73eb50039c923a19456ba339e557c7a0b59fc2b76e463dd54dd5e3ff',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'title': 'virtual-machine-scale-sets-placement-groups',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6815421959553533,
#     'preview': 'title virtual machine scale sets and placement groups description what you need to know about large azure virtual machine scale sets in order to use them in your application author mimckitt ms author …'},
#    {'chunk_id': '162dee68b71e7da4734d0ae355f4df86f05137682b1ddc3e88e07fb0b8c2e944',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-manage-powershell.md',
#     'title': 'virtual-machine-scale-sets-manage-powershell',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-manage-powershell.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6759886038350079,
#     'preview': 'title manage virtual machine scale sets with azure powershell description common azure powershell cmdlets to manage virtual machine scale sets such as how to start and stop an instance or change the s…'},
#    {'chunk_id': 'd5d9b31f8a367e73768a1d3bdfd0fcfb21c625aa067db4f45dca0263b311eff2',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'title': 'virtual-machine-scale-sets-placement-groups',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-placement-groups.md',
#     'chunk_index': 1,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6736486410743957,
#     'preview': 'data disks large scale sets enable you to deploy a scalable infrastructure consisting of thousands of vcpus and petabytes of storage as a single operation placement groups what makes a _large_ scale s…'},
#    {'chunk_id': '67e19723ab1c51684fe982143fbaeb0828e30fd7e836ed0dbef158635e69a7f0',
#     'doc_id': 'virtual-machine-scale-sets/virtual-machine-scale-sets-upgrade-scale-set.md',
#     'title': 'virtual-machine-scale-sets-upgrade-scale-set',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/virtual-machine-scale-sets-upgrade-scale-set.md',
#     'chunk_index': 0,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.6680919525990963,
#     'preview': 'title modify an azure virtual machine scale set description learn how to modify and update an azure virtual machine scale set with the rest apis azure powershell and azure cli author mimckitt ms autho…'}],
#   'eval': {'evaluation_id': '708229b8-f42f-40ed-8d97-6e59733ccebb',
#    'retrieval_relevance': 5,
#    'answer_relevance': 5,
#    'faithfulness': 5,
#    'notes': 'The retrieved excerpts provide relevant information about Azure VM Scale Sets, including their features and management, which directly supports the answer provided.'}},
#  {'query_id': '603f8671-d355-4e73-a3bf-b60971f83562',
#   'question': 'How does Azure handle VM disk persistence?',
#   'answer': 'Azure handles VM disk persistence by ensuring that disks, network interfaces (NICs), and public IPs associated with a virtual machine (VM) are persisted when the VM is deleted by default. This means that when a VM is deleted, these resources remain intact unless configured otherwise. \n\nTo manage this behavior, you can update the settings of these resources to ensure they are not automatically deleted with the VM. Specifically, you can set the `deleteOption` property to `detach`, which allows the disks, NICs, and public IPs to persist even after the VM is deleted. This feature provides flexibility in managing resources and helps maintain the infrastructure without losing associated storage and network configurations. \n\nAdditionally, Azure Managed Disks are designed for high durability and availability, providing multiple replicas of data to ensure persistence and resilience against failures.',
#   'sources': [{'chunk_id': '9568b4d1727dc508759fe71197e0031ad482196f3515fe62fe08f1aef16fffb3',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.6160208725855844,
#     'preview': 'title overview of azure disk storage description get an overview azure managed disks which handle the storage accounts for you when you re using virtual machines author roygara ms service azure disk s…'},
#    {'chunk_id': '19070d1dc7b14a46a6d58d254935f8db3a97b39aa99ac74e3865783a30a54e6e',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 5,
#     'category': 'virtual-machines',
#     'score': 0.6034223604573827,
#     'preview': 'more flexibility and scalability performance isolation easier maintenance improved security and access control for more information on these benefits see why should i use the data disk to store applic…'},
#    {'chunk_id': '74d369c1bcb00e1682667b9644afca81865bce5d966d6a6fdecc7b25bfcd8a53',
#     'doc_id': 'virtual-machines/delete.md',
#     'title': 'delete',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/delete.md',
#     'chunk_index': 6,
#     'category': 'virtual-machines',
#     'score': 0.5969797661373566,
#     'preview': 'vms just the way you would for on demand vms q how do i persist the disks nic and public ips associated with a vm a by default disks nics and public ips associated with a vm are persisted when the vm …'},
#    {'chunk_id': '592e3f4504df3c14e7a570d9acf88e38c4795b010f8a11d2bd9d7a5bb1d8683f',
#     'doc_id': 'virtual-machines/managed-disks-overview.md',
#     'title': 'managed-disks-overview',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/managed-disks-overview.md',
#     'chunk_index': 1,
#     'category': 'virtual-machines',
#     'score': 0.59638129775906,
#     'preview': 'durability for infrastructure as a service iaas disks with a 0 annualized failure rate locally redundant storage lrs disks provide at least 99 999999999 11 9 s of durability over a year zone redundant…'},
#    {'chunk_id': '1f50e8093d51dd93889047711126a53db1b373b2b53e8fc301716a602ca545bc',
#     'doc_id': 'virtual-machine-scale-sets/tutorial-use-disks-cli.md',
#     'title': 'tutorial-use-disks-cli',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/tutorial-use-disks-cli.md',
#     'chunk_index': 1,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5833669737681982,
#     'preview': 'the vm instance s operating system by default the os disk is labeled dev sda on linux and c on windows the disk caching configuration of the os disk is optimized for os performance because of this con…'}],
#   'eval': {'evaluation_id': '86ffdda9-9580-465e-89f0-1eb36a72c1de',
#    'retrieval_relevance': 5,
#    'answer_relevance': 5,
#    'faithfulness': 5,
#    'notes': 'The retrieved excerpts directly support the answer regarding VM disk persistence in Azure. The answer accurately reflects the information provided in the excerpts, particularly from source [3], which explicitly states that disks, NICs, and public IPs are persisted by default when a VM is deleted, and how to manage this behavior.'}},
#  {'query_id': '827800ec-0f48-42e2-8ba9-77686e23eba4',
#   'question': 'What is the difference between Spot VM and normal VM?',
#   'answer': 'The primary differences between Azure Spot Virtual Machines (VMs) and normal (standard) VMs are as follows:\n\n1. **Cost**: Spot VMs are significantly cheaper than standard VMs because they utilize unused Azure capacity. This cost-saving feature makes them ideal for workloads that can tolerate interruptions.\n\n2. **Eviction Policy**: Spot VMs can be evicted at any time when Azure needs the capacity back, with only 30 seconds notice. In contrast, standard VMs do not face eviction and provide guaranteed availability.\n\n3. **Service Level Agreement (SLA)**: Spot VMs do not come with an SLA, meaning there are no high availability guarantees. Standard VMs, on the other hand, typically have SLAs that ensure uptime and availability.\n\n4. **Workload Suitability**: Spot VMs are best suited for interruptible workloads such as batch processing jobs, development and testing environments, and large compute workloads. Standard VMs are more appropriate for production workloads that require consistent availability.\n\n5. **Eviction Policy Options**: When creating Spot VMs, users can set an eviction policy to either deallocate (stop the VM but retain the underlying disk) or delete (remove the VM and its disk) when evicted. Standard VMs do not have such policies since they are not subject to eviction.\n\n6. **Quota Management**: Spot VMs have a separate quota pool, and users can request additional quota specifically for Spot VMs. Standard VMs share a different quota pool.\n\nIn summary, Spot VMs offer a cost-effective solution for non-critical workloads that can handle interruptions, while standard VMs provide reliability and guaranteed availability for critical applications.',
#   'sources': [{'chunk_id': 'e2e19f61dc292776f305e00b590acb4ca1de9fc7439367788bc9db71bcb2adc6',
#     'doc_id': 'virtual-machines/spot-vms.md',
#     'title': 'spot-vms',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-vms.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.5706336607208903,
#     'preview': 'title use azure spot virtual machines description learn how to use azure spot virtual machines to save on costs author cynthn ms author cynthn ms service azure virtual machines ms subservice azure spo…'},
#    {'chunk_id': '728f45c90ed634daa4bd17f0b1d06e5f552873646624fdf53d328f7aa5be67cb',
#     'doc_id': 'virtual-machine-scale-sets/spot-priority-mix.md',
#     'title': 'spot-priority-mix',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machine-scale-sets/spot-priority-mix.md',
#     'chunk_index': 5,
#     'category': 'virtual-machine-scale-sets',
#     'score': 0.5579110085498024,
#     'preview': 'vms which is 2 standard and 8 spot to maintain the 25 75 ratio the 10 deallocated vms remain deallocated troubleshooting if spot priority mix isn t available to you be sure to configure the prioritymi…'},
#    {'chunk_id': '4b6f5b57878650c9f225d5793e4c6960648942c59f84c5c3b1e4d46ff84ef967',
#     'doc_id': 'virtual-machines/spot-vms.md',
#     'title': 'spot-vms',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-vms.md',
#     'chunk_index': 2,
#     'category': 'virtual-machines',
#     'score': 0.5535066415172047,
#     'preview': 'the following vm sizes aren t supported for azure spot virtual machines b series promo versions of any size like dv2 nv nc h promo sizes azure spot virtual machines can be deployed to any region excep…'},
#    {'chunk_id': '25a03fc9ba0e1da70d5d021f1e0a49792ec20254d08f3626061f82c84d9d8702',
#     'doc_id': 'virtual-machines/spot-vms.md',
#     'title': 'spot-vms',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-vms.md',
#     'chunk_index': 4,
#     'category': 'virtual-machines',
#     'score': 0.5507843837408594,
#     'preview': 'no sla for azure spot virtual machines and they can be evicted at any time q what to do when you get evicted but still need capacity a we recommend you use standard vms instead of azure spot virtual m…'},
#    {'chunk_id': '2ddab2aa35ee510339fc63d86f9e969dd3349747890a801557b18e08b3cb234e',
#     'doc_id': 'virtual-machines/spot-portal.md',
#     'title': 'spot-portal',
#     'url': 'https://github.com/MicrosoftDocs/azure-compute-docs/blob/main/articles/virtual-machines/spot-portal.md',
#     'chunk_index': 0,
#     'category': 'virtual-machines',
#     'score': 0.5408841179076355,
#     'preview': 'title use the portal to deploy azure spot virtual machines description how to use the portal to deploy spot virtual machines author cynthn ms service azure virtual machines ms subservice azure spot vm…'}],
#   'eval': {'evaluation_id': 'e6bc3674-49ae-4740-9c95-5dcb9c01091d',
#    'retrieval_relevance': 5,
#    'answer_relevance': 5,
#    'faithfulness': 5,
#    'notes': 'The retrieved excerpts provide comprehensive information that directly supports the answer regarding the differences between Spot VMs and normal VMs, including cost, eviction policy, SLA, workload suitability, and quota management.'}}]
